# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/bhudharhita.te/Downloads/SalesJan2009.csv')
print(df)
# Out:
#     Transaction_date   Product Price Payment_Type               Name  \
# 0        1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1        1/2/09 4:53  Product1  1200         Visa             Betina
# 2       1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3       1/3/09 14:44  Product1  1200         Visa              Gouya
# 4       1/4/09 12:56  Product2  3600         Visa            Gerd W
# 5       1/4/09 13:19  Product1  1200         Visa           LAURENCE
# 6       1/4/09 20:11  Product1  1200   Mastercard              Fleur
# 7       1/2/09 20:09  Product1  1200   Mastercard               adam
# 8       1/4/09 13:17  Product1  1200   Mastercard    Renee Elisabeth
# 9       1/4/09 14:11  Product1  1200         Visa              Aidan
# 10       1/5/09 2:42  Product1  1200       Diners              Stacy
# 11       1/5/09 5:39  Product1  1200         Amex              Heidi
# 12       1/2/09 9:16  Product1  1200   Mastercard              Sean
# ...

# %%
df['Transaction_date'] = pd.to_datetime(df.Transaction_date)
df1 = df.sort_values('Transaction_date') # This now sorts in date order
dfnew = df1.reset_index(drop=True)
print(dfnew)
# Out:
#        Transaction_date   Product Price Payment_Type            Name  \
# 0   2009-01-01 01:26:00  Product1  1200   Mastercard           Nikki
# 1   2009-01-01 01:51:00  Product1  1200   Mastercard              Si
# 2   2009-01-01 02:09:00  Product1  1200   Mastercard          Saraya
# 3   2009-01-01 02:24:00  Product1  1200         Visa            Lisa
# 4   2009-01-01 03:51:00  Product1  1200   Mastercard           sunny
# 5   2009-01-01 04:24:00  Product3  7500         Amex          Pamela
# 6   2009-01-01 05:04:00  Product1  1200   Mastercard          Regina
# 7   2009-01-01 06:29:00  Product1  1200   Mastercard          Elaine
# 8   2009-01-01 07:09:00  Product1  1200         Amex            Emer
# 9   2009-01-01 08:09:00  Product1  1200   Mastercard          Nicole
# 10  2009-01-01 09:21:00  Product1  1200       Diners            Babs
# 11  2009-01-01 09:35:00  Product1  1200   Mastercard         Barbara
# 12  2009-01-01 10:06:00  Product2  3600   Mastercard           Irene
# ...

# %%
start = input("Enter starting date & time (YYYY-MM-DD HH:MM:SS): ")
end = input("Enter ending date & time (YYYY-MM-DD HH:MM:SS): ")
# Out:
# Enter starting date & time (YYYY-MM-DD HH:MM:SS):  2009-01-01 00:00:00
# Enter ending date & time (YYYY-MM-DD HH:MM:SS):  2009-01-02 00:00:00

# %%
dfdate = dfnew[(dfnew['Transaction_date'] > start) & (dfnew['Transaction_date'] <= end)]
print(dfdate)
# Out:
#       Transaction_date   Product Price Payment_Type       Name  \
# 0  2009-01-01 01:26:00  Product1  1200   Mastercard      Nikki
# 1  2009-01-01 01:51:00  Product1  1200   Mastercard         Si
# 2  2009-01-01 02:09:00  Product1  1200   Mastercard     Saraya
# 3  2009-01-01 02:24:00  Product1  1200         Visa       Lisa
# 4  2009-01-01 03:51:00  Product1  1200   Mastercard      sunny
# 5  2009-01-01 04:24:00  Product3  7500         Amex     Pamela
# 6  2009-01-01 05:04:00  Product1  1200   Mastercard     Regina
# 7  2009-01-01 06:29:00  Product1  1200   Mastercard     Elaine
# 8  2009-01-01 07:09:00  Product1  1200         Amex       Emer
# 9  2009-01-01 08:09:00  Product1  1200   Mastercard     Nicole
# 10 2009-01-01 09:21:00  Product1  1200       Diners       Babs
# 11 2009-01-01 09:35:00  Product1  1200   Mastercard    Barbara
# 12 2009-01-01 10:06:00  Product2  3600   Mastercard      Irene
# 13 2009-01-01 11:05:00  Product1  1200       Diners      Janis
# ...

# %%
dfdate.Latitude
# Out:
# 0     40.911390
# 1     55.816667
# 2     51.050000
# 3     29.619440
# 4     52.350000
# 5     42.946940
# 6     53.133333
# 7     45.550000
# 8     26.705280
# 9    -37.833333
# 10    53.816667
# 11    34.224170
# 12    48.150000
# 13    51.863056
# 14    47.250280
# 15    35.920278
# 16    47.166667
# 17    50.700000
# 18    51.700000
# 19    58.966667
# 20    53.583333
# 21    39.083890
# 22    37.563060
# 23    43.666667
# 24    40.612780
# 25    51.083333
# 26   -38.416667
# Name: Latitude, dtype: float64

# %%
dfdate.loc['Sender Name'] = 'Phrare'
# Out:
# c:\users\bhudharhita.te\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
